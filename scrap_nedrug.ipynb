# %% [markdown]
# <a href="https://colab.research.google.com/github/juanmed/dw_a/blob/main/scrap_nedrug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import requests
import shutil
import pathlib as pl
import pandas as pd

# %%
save_path="./sample_data/"

nedrug_url="https://nedrug.mfds.go.kr/searchDrug/getExcel?sort=&sortOrder=&searchYn=&page=1&searchDivision=detail&itemName=&entpName=&ingrName1=&ingrName2=&ingrName3=&itemSeq=&stdrCodeName=&atcCodeName={}&indutyClassCode=&sClassNo=&narcoticKindCode=&cancelCode=&etcOtcCode=&makeMaterialGb=&searchConEe=AND&eeDocData=&searchConUd=AND&udDocData=&searchConNb=AND&nbDocData=&startPermitDate=&endPermitDate=&excelSearchCnt={}"

def query_api(atc_code):

	url = nedrug_url.format(atc_code,1000)

	with open(save_path + atc_code + ".xlsx", 'wb') as handle:
	    response = requests.get(url, stream=True)

	    print("Now getting {}".format(atc_code))

	    if not response.ok:
	        print (response)

	    shutil.copyfileobj(response.raw, handle)

# %%
def query_api2(atc_code, file_name):
    params = {}
    query_url = nedrug_url.format(atc_code)
    r = requests.get(url=query_url)
    print(r)
    data = r.json()

    path, filename = os.path.split(file_name)
    if not os.path.exists(path):
        pl.Path(path).mkdir(parents=True, exist_ok=True)

    with open(file_name, 'w', encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=4)

# %%
atc_code = "R05DB27"
query_api(atc_code)
#query_api2(atc_code,save_path + atc_code +".json" )
df = pd.read_excel(save_path + atc_code + ".xlsx", header=0)
df.tail()
# Out:
# Now getting R05DB27
#         품목기준코드               제품명         업체명  ... 묶음의약품정보 e은약요  수입제조국
# 124  200701202   프로피진정(레보드로프로피진)     태극제약(주)  ...     NaN  NaN    NaN
# 125  200701876    피드로정(레보드로프로피진)  한국프라임제약(주)  ...     NaN  NaN    NaN
# 126  201701330  하이로진시럽(레보드로프로피진)  (주)화이트생명과학  ...     NaN  NaN    NaN
# 127  201309451   하이로진정(레보드로프로피진)  (주)화이트생명과학  ...     NaN  NaN    NaN
# 128  201403870   휴로피진정(레보드로프로피진)   (주)휴비스트제약  ...     NaN  NaN    NaN
#
# [5 rows x 27 columns]
